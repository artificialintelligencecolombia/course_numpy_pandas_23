# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.random.randint(0,1000,100)
plt.plot(data) # plot creation

# %%
# figure object is the parent of the plot.
fig = plt.figure()
ax1 = fig.add_subplot(5,1,2)

print(fig)
# Out:
# Figure(640x480)
